# %% [markdown]
# # **Predicting Employee Retention**

# %% [markdown]
# ### Objective
#
# The objective of this assignment is to develop a Logistic Regression model. You will be using this model to analyse and predict binary outcomes based on the input data. This assignment aims to enhance understanding of logistic regression, including its assumptions, implementation, and evaluation, to effectively classify and interpret data.

# %% [markdown]
# ### Business Objective
#
# A mid-sized technology company wants to improve its understanding of employee retention to foster a loyal and committed workforce. While the organization has traditionally focused on addressing turnover, it recognises the value of proactively identifying employees likely to stay and understanding the factors contributing to their loyalty.
#
#
# In this assignment you’ll be building a logistic regression model to predict the likelihood of employee retention based on the data such as demographic details, job satisfaction scores, performance metrics, and tenure. The aim is to provide the HR department with actionable insights to strengthen retention strategies, create a supportive work environment, and increase the overall stability and satisfaction of the workforce.

# %% [markdown]
# ## Assignment Tasks
#
# You need to perform the following steps to complete this assignment:
# 1. Data Understanding
# 2. Data Cleaning
# 3. Train Validation Split
# 4. EDA on training data
# 5. EDA on validation data [Optional]
# 6. Feature Engineering
# 7. Model Building
# 8. Prediction and Model Evaluation

# %% [markdown]
# ## Data Dictionary
#
# The data has 24 Columns and 74610 Rows. Following data dictionary provides the description for each column present in dataset:<br>
#
# <table>
#   <thead>
#     <tr>
#       <th>Column Name</th>
#       <th>Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Employee ID</td>
#       <td>A unique identifier assigned to each employee.</td>
#     </tr>
#     <tr>
#       <td>Age</td>
#       <td>The age of the employee, ranging from 18 to 60 years.</td>
#     </tr>
#     <tr>
#       <td>Gender</td>
#       <td>The gender of the employee.</td>
#     </tr>
#     <tr>
#       <td>Years at Company</td>
#       <td>The number of years the employee has been working at the company.</td>
#     </tr>
#     <tr>
#       <td>Monthly Income</td>
#       <td>The monthly salary of the employee, in dollars.</td>
#     </tr>
#     <tr>
#       <td>Job Role</td>
#       <td>The department or role the employee works in, encoded into categories such as Finance, Healthcare, Technology, Education, and Media.</td>
#     </tr>
#     <tr>
#       <td>Work-Life Balance</td>
#       <td>The employee's perceived balance between work and personal life (Poor, Below Average, Good, Excellent).</td>
#     </tr>
#     <tr>
#       <td>Job Satisfaction</td>
#       <td>The employee's satisfaction with their job (Very Low, Low, Medium, High).</td>
#     </tr>
#     <tr>
#       <td>Performance Rating</td>
#       <td>The employee's performance rating (Low, Below Average, Average, High).</td>
#     </tr>
#     <tr>
#       <td>Number of Promotions</td>
#       <td>The total number of promotions the employee has received.</td>
#     </tr>
#      </tr>
#      <tr>
#       <td>Overtime</td>
#       <td>Number of overtime hours.</td>
#     </tr>
#     <tr>
#       <td>Distance from Home</td>
#       <td>The distance between the employee's home and workplace, in miles.</td>
#     </tr>
#     <tr>
#       <td>Education Level</td>
#       <td>The highest education level attained by the employee (High School, Associate Degree, Bachelor’s Degree, Master’s Degree, PhD).</td>
#     </tr>
#     <tr>
#       <td>Marital Status</td>
#       <td>The marital status of the employee (Divorced, Married, Single).</td>
#     </tr>
#      <tr>
#       <td>Number of Dependents</td>
#       <td>Number of dependents the employee has.</td>
#     </tr>
#     <tr>
#       <td>Job Level</td>
#       <td>The job level of the employee (Entry, Mid, Senior).</td>
#     </tr>
#     <tr>
#       <td>Company Size</td>
#       <td>The size of the company the employee works for (Small, Medium, Large).</td>
#     </tr>
#     <tr>
#       <td>Company Tenure (In Months)</td>
#       <td>The total number of years the employee has been working in the industry.</td>
#     </tr>
#     <tr>
#       <td>Remote Work</td>
#       <td>Whether the employee works remotely (Yes or No).</td>
#     </tr>
#     <tr>
#       <td>Leadership Opportunities</td>
#       <td>Whether the employee has leadership opportunities (Yes or No).</td>
#     </tr>
#     <tr>
#       <td>Innovation Opportunities</td>
#       <td>Whether the employee has opportunities for innovation (Yes or No).</td>
#     </tr>
#     <tr>
#       <td>Company Reputation</td>
#       <td>The employee's perception of the company's reputation (Very Poor, Poor, Good, Excellent).</td>
#     </tr>
#     <tr>
#       <td>Employee Recognition</td>
#       <td>The level of recognition the employee receives(Very Low, Low, Medium, High).</td>
#     </tr>
#     <tr>
#       <td>Attrition</td>
#       <td>Whether the employee has left the company.</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## **1. Data Understanding**
#
# In this step, load the dataset and check basic statistics of the data, including preview of data, dimension of data, column descriptions and data types.

# %% [markdown]
# ### **1.0 Import Libraries**

# %%
# Supress unnecessary warnings
import warnings
warnings.filterwarnings('ignore')

# %%
# Import the libraries
import numpy as np
import pandas as pd

# %% [markdown]
# ### **1.1 Load the Data**

# %%
# Load the dataset
dataset = pd.read_csv('Employee_data.csv')

# %%
# Check the first few entries
dataset.head(5)
# Out:
#    Employee ID  Age  Gender  Years at Company    Job Role  Monthly Income  \
# 0         8410   31    Male                19   Education            5390
# 1        64756   59  Female                 4       Media            5534
# 2        30257   24  Female                10  Healthcare            8159
# 3        65791   36  Female                 7   Education            3989
# 4        65026   56    Male                41   Education            4821
#
#   Work-Life Balance Job Satisfaction Performance Rating  Number of Promotions  \
# 0         Excellent           Medium            Average                     2
# 1              Poor             High                Low                     3
# 2              Good             High                Low                     0
# 3              Good             High               High                     1
# 4              Fair        Very High            Average                     0
#
# ...

# %%
# Inspect the shape of the dataset
dataset.shape
# Out:
# (74610, 24)

# %%
# Inspect the different columns in the dataset
list(dataset.columns)
# Out:
# ['Employee ID',
#  'Age',
#  'Gender',
#  'Years at Company',
#  'Job Role',
#  'Monthly Income',
#  'Work-Life Balance',
#  'Job Satisfaction',
#  'Performance Rating',
#  'Number of Promotions',
#  'Overtime',
#  'Distance from Home',
#  'Education Level',
#  'Marital Status',
#  'Number of Dependents',
#  'Job Level',
#  'Company Size',
#  'Company Tenure (In Months)',
#  'Remote Work',
#  'Leadership Opportunities',
#  'Innovation Opportunities',
#  'Company Reputation',
#  'Employee Recognition',
#  'Attrition']

# %% [markdown]
# ### **1.2 Check the basic statistics**

# %%
# Check the summary of the dataset
dataset.describe()
# Out:
#         Employee ID           Age  Years at Company  Monthly Income  \
# count  74610.000000  74610.000000      74610.000000    74610.000000
# mean   37246.028696     38.529379         15.722638     7344.931417
# std    21505.785344     12.082299         11.224059     2596.373589
# min        1.000000     18.000000          1.000000     1226.000000
# 25%    18624.250000     28.000000          7.000000     5652.000000
# 50%    37239.500000     39.000000         13.000000     7348.500000
# 75%    55871.750000     49.000000         23.000000     8876.000000
# max    74498.000000     59.000000         51.000000    50030.000000
#
#        Number of Promotions  Distance from Home  Number of Dependents  \
# count          74610.000000        72698.000000          74610.000000
# mean               0.832958           49.990839              1.657432
# std                0.995326           28.519135              1.579862
# min                0.000000            1.000000              0.000000
# ...

# %% [markdown]
# ### **1.3 Check the data type of columns**

# %%
# Check the info to see the types of the feature variables and the null values present
print(dataset.dtypes)
# Out:
# Employee ID                     int64
# Age                             int64
# Gender                         object
# Years at Company                int64
# Job Role                       object
# Monthly Income                  int64
# Work-Life Balance              object
# Job Satisfaction               object
# Performance Rating             object
# Number of Promotions            int64
# Overtime                       object
# Distance from Home            float64
# Education Level                object
# Marital Status                 object
# Number of Dependents            int64
# Job Level                      object
# Company Size                   object
# Company Tenure (In Months)    float64
# Remote Work                    object
# Leadership Opportunities       object
# Innovation Opportunities       object
# Company Reputation             object
# Employee Recognition           object
# Attrition                      object
# dtype: object

# %% [markdown]
# ## **2. Data Cleaning** <font color = red>[15 marks]</font>

# %% [markdown]
# ### **2.1 Handle the missing values** <font color = red>[10 marks]</font>

# %% [markdown]
# 2.1.1 Check the number of missing values <font color="red">[2 Mark]</font>

# %%
# Check the number of missing values in each column
dataset.isnull().sum()
# Out:
# Employee ID                      0
# Age                              0
# Gender                           0
# Years at Company                 0
# Job Role                         0
# Monthly Income                   0
# Work-Life Balance                0
# Job Satisfaction                 0
# Performance Rating               0
# Number of Promotions             0
# Overtime                         0
# Distance from Home            1912
# Education Level                  0
# Marital Status                   0
# Number of Dependents             0
# Job Level                        0
# Company Size                     0
# Company Tenure (In Months)    2413
# Remote Work                      0
# Leadership Opportunities         0
# Innovation Opportunities         0
# Company Reputation               0
# Employee Recognition             0
# Attrition                        0
# dtype: int64

# %% [markdown]
# 2.1.2 Check the percentage of missing values <font color="red">[2 Marks]</font>

# %%
# Check the percentage of missing values in each column
missing_percentage = dataset.isnull().mean() * 100
print(missing_percentage)
# Out:
# Employee ID                   0.000000
# Age                           0.000000
# Gender                        0.000000
# Years at Company              0.000000
# Job Role                      0.000000
# Monthly Income                0.000000
# Work-Life Balance             0.000000
# Job Satisfaction              0.000000
# Performance Rating            0.000000
# Number of Promotions          0.000000
# Overtime                      0.000000
# Distance from Home            2.562659
# Education Level               0.000000
# Marital Status                0.000000
# Number of Dependents          0.000000
# Job Level                     0.000000
# Company Size                  0.000000
# Company Tenure (In Months)    3.234151
# Remote Work                   0.000000
# Leadership Opportunities      0.000000
# Innovation Opportunities      0.000000
# Company Reputation            0.000000
# Employee Recognition          0.000000
# Attrition                     0.000000
# ...

# %% [markdown]
# 2.1.3 Handle rows with missing values <font color="red">[4 Marks]</font>

# %%
# Handle the missing value rows in the column
# Column	                           Missing%       Data Distribution
# Distance from Home	               2.56%          Likely skewed (1 to 99 miles), mean ≈ 50, median = 50 (Impute with Median)
# Company Tenure (Months)	           3.23%          mean ≈ 56, std ≈ 25 median is safe, especially if the distribution is skewed.
# Only 2 columns have missing values, and the missing percentage is low (<5%), which makes imputation a safe and effective strategy.

# dataset['Distance from Home'].fillna(dataset['Distance from Home'].median(), inplace=True)
# dataset['Company Tenure (In Months)'].fillna(dataset['Company Tenure (In Months)'].median(), inplace=True)

## However based on required question drop the rows with missing values.
dataset_cleaned = dataset.dropna(subset=['Distance from Home', 'Company Tenure (In Months)'])

# Dataset shape after droping
dataset_cleaned.shape
# Out:
# (70635, 24)

# %% [markdown]
# 2.1.4 Check percentage of remaning data after missing values are removed <font color="red">[2 Mark]</font>

# %%
# Check the percentage of remaining data after missing values are removed
original_rows = dataset.shape[0] # Based on your dataset info

# New total rows
remaining_rows = dataset_cleaned.shape[0]

# Calculate percentage remaining
percentage_remaining = (remaining_rows / original_rows) * 100
print(f"Percentage of dataset remaining: {percentage_remaining:.2f}%")
# Out:
# Percentage of dataset remaining: 94.67%

# %% [markdown]
# ### **2.2 Identify and handle redundant values within categorical columns (if any)** <font color = red>[3 marks]</font>

# %% [markdown]
# Examine the categorical columns to determine if any value or column needs to be treated

# %%
# Write a function to display the categorical columns with their unique values and check for redundant values
def display_categorical_columns_info(df):
    """
    Display all categorical columns and their unique values.
    Useful for spotting inconsistent or redundant entries.
    """
    # Select columns with object or category data types
    cat_cols = df.select_dtypes(include=['object', 'category']).columns

    print(f"Found {len(cat_cols)} categorical columns.\n")

    for col in cat_cols:
        unique_vals = df[col].unique()
        print(f"Column: {col}")
        print(f"Unique Values ({len(unique_vals)}): {sorted(unique_vals)}\n")

# %%
# Check the data
display_categorical_columns_info(dataset_cleaned)
# Out:
# Found 16 categorical columns.
#
# Column: Gender
# Unique Values (2): ['Female', 'Male']
#
# Column: Job Role
# Unique Values (5): ['Education', 'Finance', 'Healthcare', 'Media', 'Technology']
#
# Column: Work-Life Balance
# Unique Values (4): ['Excellent', 'Fair', 'Good', 'Poor']
#
# Column: Job Satisfaction
# Unique Values (4): ['High', 'Low', 'Medium', 'Very High']
#
# Column: Performance Rating
# Unique Values (4): ['Average', 'Below Average', 'High', 'Low']
#
# Column: Overtime
# Unique Values (2): ['No', 'Yes']
#
# Column: Education Level
# Unique Values (5): ['Associate Degree', 'Bachelorâ€™s Degree', 'High School', 'Masterâ€™s Degree', 'PhD']
#
# Column: Marital Status
# Unique Values (3): ['Divorced', 'Married', 'Single']
#
# Column: Job Level
# Unique Values (3): ['Entry', 'Mid', 'Senior']
#
# Column: Company Size
# Unique Values (3): ['Large', 'Medium', 'Small']
#
# Column: Remote Work
# Unique Values (2): ['No', 'Yes']
#
# Column: Leadership Opportunities
# ...

# %% [markdown]
# ### **2.3 Drop redundant columns** <font color = red>[2 marks]</font>

# %%
# Drop redundant columns which are not required for modelling (columns like Columns Employee ID are unique for each row and Company Tenure (In Months) is very similar to Years at Company are similar so droping).

redundant_cols = ['Employee ID', 'Years at Company']  # Add more if needed
dataset_cleaned.drop(columns=redundant_cols, inplace=True)

# %%
# Check first few rows of data
dataset_cleaned.head(5)
# Out:
#    Age  Gender    Job Role  Monthly Income Work-Life Balance Job Satisfaction  \
# 0   31    Male   Education            5390         Excellent           Medium
# 1   59  Female       Media            5534              Poor             High
# 2   24  Female  Healthcare            8159              Good             High
# 3   36  Female   Education            3989              Good             High
# 4   56    Male   Education            4821              Fair        Very High
#
#   Performance Rating  Number of Promotions Overtime  Distance from Home  ...  \
# 0            Average                     2       No                22.0  ...
# 1                Low                     3       No                21.0  ...
# 2                Low                     0       No                11.0  ...
# 3               High                     1       No                27.0  ...
# 4            Average                     0      Yes                71.0  ...
#
# ...

# %% [markdown]
# ## **3. Train-Validation Split** <font color = red>[5 marks]</font>

# %% [markdown]
# ### **3.1 Import required libraries**

# %%
# Import Train Test Split
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### **3.2 Define feature and target variables** <font color = red>[2 Mark]</font>

# %%
# Put all the feature variables in X

X = dataset_cleaned.drop(columns=['Attrition'])  # Features

# Put the target variable in y
y = dataset_cleaned['Attrition']                  # Target

# %% [markdown]
# ### **3.3 Split the data** <font color="red">[3 Marks]</font>

# %%
# Split the data into 70% train data and 30% validation data
X_train, X_val, y_train, y_val = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# %% [markdown]
# ## **4. EDA on training data** <font color = red>[20 marks]</font>

# %% [markdown]
# ### **4.1 Perform univariate analysis** <font color = red>[6 marks]</font>

# %% [markdown]
# Perform univariate analysis on training data for all the numerical columns.

# %% [markdown]
# 4.1.1 Select numerical columns from training data <font color = "red">[1 Mark]</font>

# %%
# Select numerical columns
numerical_cols = X_train.select_dtypes(include=['int64', 'float64']).columns
print("Numerical columns:", list(numerical_cols))
# Out:
# Numerical columns: ['Age', 'Monthly Income', 'Number of Promotions', 'Distance from Home', 'Number of Dependents', 'Company Tenure (In Months)']

# %% [markdown]
# 4.1.2 Plot distribution of numerical columns <font color = "red">[5 Marks]</font>

# %%
# Plot all the numerical columns to understand their distribution

# Import necessary libraries
import seaborn as sns
import matplotlib.pyplot as plt

# Set style for plots
sns.set(style="whitegrid")

# Number of numerical columns
num_cols = len(numerical_cols)

# Set figure size (adjust height based on number of plots)
plt.figure(figsize=(12, num_cols * 4))

for i, col in enumerate(numerical_cols, 1):
    plt.subplot(num_cols, 1, i)
    sns.histplot(X_train[col], kde=True, bins=30, color='skyblue')
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### **4.2 Perform correlation analysis** <font color="red">[4 Marks]</font>

# %% [markdown]
# Check the correlation among different numerical variables.

# %%
# Create correlation matrix for numerical columns
corr_matrix = X_train[numerical_cols].corr()

# Set figure size
plt.figure(figsize=(10, 8))

# Plot Heatmap of the correlation matrix
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap='coolwarm', center=0)

plt.title("Correlation Matrix Heatmap for Numerical Features")
plt.show()

# %% [markdown]
# ### **4.3 Check class balance** <font color="red">[2 Marks]</font>

# %% [markdown]
# Check the distribution of target variable in training set to check class balance.

# %%
# Plot a bar chart to check class balance
plt.figure(figsize=(6,4))
sns.countplot(x=y_train)
plt.title('Class Distribution in Training Data')
plt.xlabel('Attrition')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### **4.4 Perform bivariate analysis** <font color="red">[8 Marks]</font>

# %% [markdown]
# Perform bivariate analysis on training data between all the categorical columns and target variable to  analyse how the categorical variables influence the target variable.

# %%
# Plot distribution for each categorical column with target variable
# Get categorical columns from X_train
categorical_cols = X_train.select_dtypes(include=['object', 'category']).columns

# Set plot style
sns.set(style="whitegrid")

# Plot countplots for each categorical column with hue as target
for col in categorical_cols:
    plt.figure(figsize=(8, 4))
    sns.countplot(data=X_train, x=col, hue=y_train, palette='Set2')
    plt.title(f'Distribution of {col} by Attrition')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## **5. EDA on validation data** <font color = red>[OPTIONAL]</font>

# %% [markdown]
# ### **5.1 Perform univariate analysis**

# %% [markdown]
# Perform univariate analysis on validation data for all the numerical columns.

# %% [markdown]
# 5.1.1 Select numerical columns from validation data

# %%
# Select numerical columns
numerical_cols_val = X_val.select_dtypes(include=['int64', 'float64']).columns
print("Numerical columns in validation data:", list(numerical_cols_val))
# Out:
# Numerical columns in validation data: ['Age', 'Monthly Income', 'Number of Promotions', 'Distance from Home', 'Number of Dependents', 'Company Tenure (In Months)']

# %% [markdown]
# 5.1.2 Plot distribution of numerical columns

# %%
# Plot all the numerical columns to understand their distribution
sns.set(style="whitegrid")

num_cols_val = X_val.select_dtypes(include=['int64', 'float64']).columns
num_plots = len(num_cols_val)

plt.figure(figsize=(12, num_plots * 4))

for i, col in enumerate(num_cols_val, 1):
    plt.subplot(num_plots, 1, i)
    sns.histplot(X_val[col], kde=True, bins=30, color='skyblue')
    plt.title(f'Distribution of {col} in Validation Data')
    plt.xlabel(col)
    plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### **5.2 Perform correlation analysis**

# %% [markdown]
# Check the correlation among different numerical variables.

# %%
# Create correlation matrix for numerical columns

# Select numerical columns in validation data
numerical_cols_val = X_val.select_dtypes(include=['int64', 'float64']).columns

# Compute correlation matrix
corr_matrix_val = X_val[numerical_cols_val].corr()

# Plot heatmap of correlation matrix
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix_val, annot=True, fmt=".2f", cmap='coolwarm', center=0)
plt.title("Correlation Matrix Heatmap for Numerical Features (Validation Data)")
plt.show()

# %% [markdown]
# ### **5.3 Check class balance**

# %% [markdown]
# Check the distribution of target variable in validation data to check class balance.

# %%
# Plot a bar chart to check class balance
plt.figure(figsize=(6,4))
sns.countplot(x=y_val)
plt.title('Class Distribution in Validation Data')
plt.xlabel('Attrition')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### **5.4 Perform bivariate analysis**

# %% [markdown]
# Perform bivariate analysis on validation data between all the categorical columns and target variable to analyse how the categorical variables influence the target variable.

# %%
# Plot distribution for each categorical column with target variable
# Select categorical columns in validation data
categorical_cols_val = X_val.select_dtypes(include=['object', 'category']).columns

sns.set(style="whitegrid")

for col in categorical_cols_val:
    plt.figure(figsize=(8, 4))
    sns.countplot(data=X_val, x=col, hue=y_val, palette='Set2')
    plt.title(f'Distribution of {col} by Attrition (Validation Data)')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## **6. Feature Engineering** <font color = red>[20 marks]</font>

# %% [markdown]
# ### **6.1 Dummy variable creation** <font color = red>[15 marks]</font>
#
#
# The next step is to deal with the categorical variables present in the data.

# %% [markdown]
# 6.1.1 Identify categorical columns where dummy variables are required <font color="red">[1 Mark]</font>

# %%
# Check the categorical columns
# Identify categorical columns in training data
categorical_cols = X_train.select_dtypes(include=['object', 'category']).columns.tolist()

print("Categorical columns requiring dummy variables:")
for col in categorical_cols:
    unique_vals = X_train[col].unique()
    print(f"{col} (unique values: {len(unique_vals)}) — {list(unique_vals)}")
# Out:
# Categorical columns requiring dummy variables:
# Gender (unique values: 2) — ['Female', 'Male']
# Job Role (unique values: 5) — ['Education', 'Finance', 'Media', 'Healthcare', 'Technology']
# Work-Life Balance (unique values: 4) — ['Fair', 'Good', 'Excellent', 'Poor']
# Job Satisfaction (unique values: 4) — ['High', 'Very High', 'Medium', 'Low']
# Performance Rating (unique values: 4) — ['Low', 'High', 'Below Average', 'Average']
# Overtime (unique values: 2) — ['No', 'Yes']
# Education Level (unique values: 5) — ['Associate Degree', 'High School', 'Bachelorâ€™s Degree', 'PhD', 'Masterâ€™s Degree']
# Marital Status (unique values: 3) — ['Single', 'Married', 'Divorced']
# Job Level (unique values: 3) — ['Entry', 'Mid', 'Senior']
# Company Size (unique values: 3) — ['Medium', 'Small', 'Large']
# Remote Work (unique values: 2) — ['No', 'Yes']
# Leadership Opportunities (unique values: 2) — ['No', 'Yes']
# Innovation Opportunities (unique values: 2) — ['No', 'Yes']
# ...

# %% [markdown]
# 6.1.2 Create dummy variables for independent columns in training set <font color="red">[3 Marks]</font>

# %%
# Create dummy variables using the 'get_dummies' for independent columns

# Identify categorical columns
categorical_cols = X_train.select_dtypes(include=['object', 'category']).columns

# Create dummy variables for categorical columns (drop_first=True to avoid multicollinearity)
dummies = pd.get_dummies(X_train[categorical_cols], drop_first=True)

# Drop original categorical columns from X_train
X_train_numeric = X_train.drop(columns=categorical_cols)

# Concatenate numeric columns and dummy variables
X_train_master = pd.concat([X_train_numeric, dummies], axis=1)

# Check the resulting DataFrame
print(X_train_master.head())
print(f"Shape before: {X_train.shape}")
print(f"Shape after dummy variable creation: {X_train_master.shape}")
# Out:
#        Age  Monthly Income  Number of Promotions  Distance from Home  \
# 41465   46            4617                     2                59.0
# 69350   43            4447                     3                64.0
# 28247   27            9762                     0                84.0
# 3217    47            5244                     2                59.0
# 73636   25            4455                     0                36.0
#
#        Number of Dependents  Company Tenure (In Months)  Gender_Male  \
# 41465                     2                        92.0        False
# 69350                     0                       103.0         True
# 28247                     1                        16.0         True
# 3217                      1                        74.0        False
# 73636                     0                        62.0        False
#
#        Job Role_Finance  Job Role_Healthcare  Job Role_Media  ...  \
# ...

# %% [markdown]
# Now, drop the original categorical columns and check the DataFrame

# %%
# Drop the original categorical columns and check the DataFrame
X_train_no_cat = X_train.drop(columns=categorical_cols)

# Display the first few rows to verify
print(X_train_no_cat.head())

# Check columns to confirm categorical columns are dropped
print("Columns after dropping categorical columns:")
print(X_train_no_cat.columns)
# Out:
#        Age  Monthly Income  Number of Promotions  Distance from Home  \
# 41465   46            4617                     2                59.0
# 69350   43            4447                     3                64.0
# 28247   27            9762                     0                84.0
# 3217    47            5244                     2                59.0
# 73636   25            4455                     0                36.0
#
#        Number of Dependents  Company Tenure (In Months)
# 41465                     2                        92.0
# 69350                     0                       103.0
# 28247                     1                        16.0
# 3217                      1                        74.0
# 73636                     0                        62.0
# Columns after dropping categorical columns:
# Index(['Age', 'Monthly Income', 'Number of Promotions', 'Distance from Home',
#        'Number of Dependents', 'Company Tenure (In Months)'],
#       dtype='object')

# %% [markdown]
# 6.1.3 Create dummy variables for independent columns in validation set <font color="red">[3 Marks]</font>

# %%
# Create dummy variables using the 'get_dummies' for independent columns

# Identify categorical columns (same as training set)
categorical_cols = X_train.select_dtypes(include=['object', 'category']).columns

# Create dummy variables for categorical columns in validation set
val_dummies = pd.get_dummies(X_val[categorical_cols], drop_first=True)

# Drop original categorical columns from validation set
X_val_numeric = X_val.drop(columns=categorical_cols)

# Align validation dummy columns to training dummy columns (add missing columns with zeros)
val_dummies = val_dummies.reindex(columns=dummies.columns, fill_value=0)

# Concatenate numeric columns and dummy variables to create master validation DataFrame
X_val_master = pd.concat([X_val_numeric, val_dummies], axis=1)

# Check the resulting DataFrame
print(X_val_master.head())
print(f"Shape before: {X_val.shape}")
print(f"Shape after dummy variable creation: {X_val_master.shape}")
# Out:
#        Age  Monthly Income  Number of Promotions  Distance from Home  \
# 23813   46            7740                     3                78.0
# 14537   32            8779                     1                91.0
# 45192   53           11683                     1                71.0
# 13765   50            7305                     2                71.0
# 3411    48           10114                     0                 2.0
#
#        Number of Dependents  Company Tenure (In Months)  Gender_Male  \
# 23813                     2                         3.0         True
# 14537                     0                        35.0         True
# 45192                     1                        39.0         True
# 13765                     1                         3.0        False
# 3411                      1                        64.0         True
#
#        Job Role_Finance  Job Role_Healthcare  Job Role_Media  ...  \
# ...

# %% [markdown]
# Now, drop the original categorical columns and check the DataFrame

# %%
# Drop categorical columns and check the DataFrame
X_val_no_cat = X_val.drop(columns=categorical_cols)

# Display the first few rows to verify
print(X_val_no_cat.head())

# Check columns to confirm categorical columns are dropped
print("Columns after dropping categorical columns in validation data:")
print(X_val_no_cat.columns)
# Out:
#        Age  Monthly Income  Number of Promotions  Distance from Home  \
# 23813   46            7740                     3                78.0
# 14537   32            8779                     1                91.0
# 45192   53           11683                     1                71.0
# 13765   50            7305                     2                71.0
# 3411    48           10114                     0                 2.0
#
#        Number of Dependents  Company Tenure (In Months)
# 23813                     2                         3.0
# 14537                     0                        35.0
# 45192                     1                        39.0
# 13765                     1                         3.0
# 3411                      1                        64.0
# Columns after dropping categorical columns in validation data:
# Index(['Age', 'Monthly Income', 'Number of Promotions', 'Distance from Home',
#        'Number of Dependents', 'Company Tenure (In Months)'],
# ...

# %% [markdown]
# 6.1.4 Create DataFrame for dependent column in both training and validation set <font color = "red">[1 Mark]</font>

# %%
# Convert y_train and y_validation to DataFrame to create dummy variables
y_train_df = pd.DataFrame(y_train, columns=['Attrition'])
y_val_df = pd.DataFrame(y_val, columns=['Attrition'])

print(y_train_df.head())
print(y_val_df.head())

# If you want to create dummy variables for y (e.g., if it's categorical):
y_train_dummies = pd.get_dummies(y_train_df['Attrition'], drop_first=True)
y_val_dummies = pd.get_dummies(y_val_df['Attrition'], drop_first=True)

print(y_train_dummies.head())
print(y_val_dummies.head())
# Out:
#       Attrition
# 41465      Left
# 69350      Left
# 28247      Left
# 3217       Left
# 73636      Left
#       Attrition
# 23813    Stayed
# 14537      Left
# 45192      Left
# 13765      Left
# 3411     Stayed
#        Stayed
# 41465   False
# 69350   False
# 28247   False
# 3217    False
# 73636   False
#        Stayed
# 23813    True
# 14537   False
# 45192   False
# 13765   False
# 3411     True

# %% [markdown]
# 6.1.5 Create dummy variables for dependent column in training set <font color="red">[3 Marks]</font>

# %%
# Create dummy variables using the 'get_dummies' for dependent column

# Assuming y_train is a pandas Series or array of the target variable
# Convert to DataFrame if needed
y_train_df = pd.DataFrame(y_train, columns=['Attrition'])

# Create dummy variables for the dependent variable (target)
y_train_dummies = pd.get_dummies(y_train_df['Attrition'], drop_first=True)

# Show the dummy variable DataFrame
print(y_train_dummies.head())

# y_train_dummies can now be used as the target variable for binary classification
# Out:
#        Stayed
# 41465   False
# 69350   False
# 28247   False
# 3217    False
# 73636   False

# %% [markdown]
# 6.1.6 Create dummy variable for dependent column in validation set <font color = "red">[3 Marks]</font>

# %%
# Create dummy variables using the 'get_dummies' for dependent column

# Convert y_val to DataFrame if it's not already
y_val_df = pd.DataFrame(y_val, columns=['Attrition'])

# Create dummy variables for the dependent variable in validation set
y_val_dummies = pd.get_dummies(y_val_df['Attrition'], drop_first=True)

# Show the dummy variables
print(y_val_dummies.head())
# Out:
#        Stayed
# 23813    True
# 14537   False
# 45192   False
# 13765   False
# 3411     True

# %% [markdown]
# 6.1.7 Drop redundant columns <font color="red">[1 Mark]</font>

# %%
# Drop redundant columns from both train and validation

# List of redundant columns to drop (example, replace with actual redundant column names)
redundant_cols = ['Employee ID', 'SomeOtherColumn']  # Add columns you want to drop

# Drop redundant columns from training data
X_train_final = X_train_master.drop(columns=redundant_cols, errors='ignore')

# Drop redundant columns from validation data
X_val_final = X_val_master.drop(columns=redundant_cols, errors='ignore')

# Check the result
print("Training data shape after dropping redundant columns:", X_train_final.shape)
print("Validation data shape after dropping redundant columns:", X_val_final.shape)
# Out:
# Training data shape after dropping redundant columns: (49444, 40)
# Validation data shape after dropping redundant columns: (21191, 40)

# %% [markdown]
# ### **6.2 Feature scaling** <font color = red>[5 marks]</font>
#
# Apply feature scaling to the numeric columns to bring them to a common range and ensure consistent scaling.

# %% [markdown]
# 6.2.1 Import required libraries <font color="red">[1 Mark]</font>

# %%
# Import the necessary scaling tool from scikit-learn
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# 6.2.2 Scale the numerical features <font color="red">[4 Marks]</font>

# %%
# Identify numerical columns in training data
numeric_cols = X_train_final.select_dtypes(include=['int64', 'float64']).columns

# Initialize the scaler
scaler = StandardScaler()

# Fit scaler on training numeric data and transform training set
X_train_final[numeric_cols] = scaler.fit_transform(X_train_final[numeric_cols])

# Transform validation numeric data using the same scaler
X_val_final[numeric_cols] = scaler.transform(X_val_final[numeric_cols])

# Check scaled data summary
print("Training data after scaling (first 5 rows):")
print(X_train_final[numeric_cols].head())

print("\nValidation data after scaling (first 5 rows):")
print(X_val_final[numeric_cols].head())
# Out:
# Training data after scaling (first 5 rows):
#             Age  Monthly Income  Number of Promotions  Distance from Home  \
# 41465  0.619633       -1.064176              1.169006            0.319585
# 69350  0.371227       -1.130434              2.172605            0.494961
# 28247 -0.953603        0.941122             -0.838194            1.196466
# 3217   0.702434       -0.819798              1.169006            0.319585
# 73636 -1.119207       -1.127316             -0.838194           -0.487146
#
#        Number of Dependents  Company Tenure (In Months)
# 41465              0.218921                    1.427790
# 69350             -1.050275                    1.860823
# 28247             -0.415677                   -1.564070
# 3217              -0.415677                    0.719192
# 73636             -1.050275                    0.246793
#
# Validation data after scaling (first 5 rows):
#             Age  Monthly Income  Number of Promotions  Distance from Home  \
# ...

# %% [markdown]
# ## **7. Model Building** <font color = red>[40 marks]</font>

# %% [markdown]
# ### **7.1 Feature selection** <font color = red>[5 marks]</font>
#
# As there are a lot of variables present in the data, Recursive Feature Elimination (RFE) will be used to select the most influential features for building the model.

# %% [markdown]
# 7.1.1 Import required libraries <font color="red">[1 Mark]</font>

# %%
# Import 'LogisticRegression' and create a LogisticRegression object
from sklearn.linear_model import LogisticRegression

# Create LogisticRegression object
logreg = LogisticRegression(random_state=42, max_iter=1000)  # setting random_state for reproducibility

# %% [markdown]
# 7.1.2 Import RFE  and select 15 variables <font color="red">[3 Mark]</font>

# %%
# Import RFE and select 15 variables
from sklearn.feature_selection import RFE

# Create RFE object to select 15 features
rfe = RFE(estimator=logreg, n_features_to_select=15)

# Fit RFE on training data
rfe.fit(X_train_final, y_train_dummies)  # y_train_dummies should be your target dummy variable

# Get the selected features mask
selected_features_mask = rfe.support_

# Get the list of selected feature names
selected_features = X_train_final.columns[selected_features_mask]

print("Selected 15 features:")
print(selected_features)
# Out:
# Selected 15 features:
# Index(['Gender_Male', 'Work-Life Balance_Fair', 'Work-Life Balance_Poor',
#        'Job Satisfaction_Low', 'Job Satisfaction_Very High',
#        'Performance Rating_Below Average', 'Performance Rating_Low',
#        'Overtime_Yes', 'Education Level_PhD', 'Marital Status_Single',
#        'Job Level_Mid', 'Job Level_Senior', 'Remote Work_Yes',
#        'Company Reputation_Fair', 'Company Reputation_Poor'],
#       dtype='object')

# %%
# Display the features selected by RFE
print("Features selected by RFE:")
for feature in selected_features:
    print(feature)
# Out:
# Features selected by RFE:
# Gender_Male
# Work-Life Balance_Fair
# Work-Life Balance_Poor
# Job Satisfaction_Low
# Job Satisfaction_Very High
# Performance Rating_Below Average
# Performance Rating_Low
# Overtime_Yes
# Education Level_PhD
# Marital Status_Single
# Job Level_Mid
# Job Level_Senior
# Remote Work_Yes
# Company Reputation_Fair
# Company Reputation_Poor

# %% [markdown]
# 7.1.3 Store the selected features <font color="red">[1 Mark]</font>

# %%
# Put columns selected by RFE into variable 'col'
col = X_train_final.columns[rfe.support_].tolist()

# Check the selected columns
print("Selected columns stored in 'col':")
print(col)
# Out:
# Selected columns stored in 'col':
# ['Gender_Male', 'Work-Life Balance_Fair', 'Work-Life Balance_Poor', 'Job Satisfaction_Low', 'Job Satisfaction_Very High', 'Performance Rating_Below Average', 'Performance Rating_Low', 'Overtime_Yes', 'Education Level_PhD', 'Marital Status_Single', 'Job Level_Mid', 'Job Level_Senior', 'Remote Work_Yes', 'Company Reputation_Fair', 'Company Reputation_Poor']

# %% [markdown]
# ### **7.2 Building Logistic Regression Model** <font color = red>[20 marks]</font>
#
# Now that you have selected the variables through RFE, use these features to build a logistic regression model with statsmodels. This will allow you to assess the statistical aspects, such as p-values and VIFs, which are important for checking multicollinearity and ensuring that the predictors are not highly correlated with each other, as this could distort the model's coefficients.

# %% [markdown]
# 7.2.1 Select relevant columns on training set <font color="red">[1 Mark]</font>

# %%
# Select only the columns selected by RFE

X_train_selected = X_train_final[col]

# Select only RFE-selected columns in validation data
X_val_selected = X_val_final[col]

# Check shapes to confirm
print("Training data shape after selecting RFE columns:", X_train_selected.shape)
print("Validation data shape after selecting RFE columns:", X_val_selected.shape)
# Out:
# Training data shape after selecting RFE columns: (49444, 15)
# Validation data shape after selecting RFE columns: (21191, 15)

# %%
# View the training data
print(X_train_selected.head())
# Out:
#        Gender_Male  Work-Life Balance_Fair  Work-Life Balance_Poor  \
# 41465        False                    True                   False
# 69350         True                   False                   False
# 28247         True                   False                   False
# 3217         False                    True                   False
# 73636        False                   False                   False
#
#        Job Satisfaction_Low  Job Satisfaction_Very High  \
# 41465                 False                       False
# 69350                 False                       False
# 28247                 False                        True
# 3217                  False                       False
# 73636                 False                       False
#
#        Performance Rating_Below Average  Performance Rating_Low  Overtime_Yes  \
# 41465                             False                    True         False
# ...

# %% [markdown]
# 7.2.2 Add constant to training set <font color = "red">[1 Mark]</font>

# %%
# Import statsmodels and add constant to training set
import statsmodels.api as sm

# Add constant (intercept) to training data
X_train_sm = sm.add_constant(X_train_selected)

# View first few rows to confirm
print(X_train_sm.head())
# Out:
#        const  Gender_Male  Work-Life Balance_Fair  Work-Life Balance_Poor  \
# 41465    1.0        False                    True                   False
# 69350    1.0         True                   False                   False
# 28247    1.0         True                   False                   False
# 3217     1.0        False                    True                   False
# 73636    1.0        False                   False                   False
#
#        Job Satisfaction_Low  Job Satisfaction_Very High  \
# 41465                 False                       False
# 69350                 False                       False
# 28247                 False                        True
# 3217                  False                       False
# 73636                 False                       False
#
#        Performance Rating_Below Average  Performance Rating_Low  Overtime_Yes  \
# 41465                             False                    True         False
# ...

# %% [markdown]
# 7.2.3 Fit logistic regression model <font color="red">[3 Marks]</font>

# %%
# Fit a logistic regression model on X_train after adding a constant and output the summary

# Ensure y_train_dummies is a 1D numeric array (Series of integers)
y_train_numeric = y_train_dummies.squeeze().astype(int)

# Ensure X_train_sm is entirely numeric
X_train_sm = X_train_sm.astype(float)

# Now fit the model

logit_model = sm.Logit(y_train_numeric, X_train_sm)
result = logit_model.fit()

# Display summary
print(result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.506106
#          Iterations 6
#                            Logit Regression Results
# ...
# Dep. Variable:                 Stayed   No. Observations:                49444
# Model:                          Logit   Df Residuals:                    49428
# Method:                           MLE   Df Model:                           15
# Date:                Thu, 29 May 2025   Pseudo R-squ.:                  0.2689
# Time:                        16:13:20   Log-Likelihood:                -25024.
# converged:                       True   LL-Null:                       -34226.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ...
#                                        coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# **Model Interpretation**
#
# The output summary table  will provide the features used for building model along with coefficient of each of the feature and their p-value. The p-value in a logistic regression model is used to assess the statistical significance of each coefficient. Lesser the p-value, more significant the feature is in the model.
#
# A positive coefficient will indicate that an increase in the value of feature would increase the odds of the event occurring. On the other hand, a negative coefficient means the opposite, i.e,  an increase in the value of feature would decrease the odds of the event occurring.

# %% [markdown]
# 7.2.4 Evaluate VIF of features <font color="red">[3 Marks]</font>

# %%
# Import 'variance_inflation_factor'
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
# Make a VIF DataFrame for all the variables present

vif_data = pd.DataFrame()
vif_data["Feature"] = X_train_sm.columns

# Calculate VIF for each feature
vif_data["VIF"] = [variance_inflation_factor(X_train_sm.values, i)
                   for i in range(X_train_sm.shape[1])]

# Display VIF DataFrame
print(vif_data)
# Out:
#                              Feature       VIF
# 0                              const  7.167050
# 1                        Gender_Male  1.000463
# 2             Work-Life Balance_Fair  1.076163
# 3             Work-Life Balance_Poor  1.076193
# 4               Job Satisfaction_Low  1.029002
# 5         Job Satisfaction_Very High  1.028895
# 6   Performance Rating_Below Average  1.009633
# 7             Performance Rating_Low  1.009969
# 8                       Overtime_Yes  1.000379
# 9                Education Level_PhD  1.000218
# 10             Marital Status_Single  1.000352
# 11                     Job Level_Mid  1.203866
# 12                  Job Level_Senior  1.203944
# 13                   Remote Work_Yes  1.000375
# 14           Company Reputation_Fair  1.067230
# 15           Company Reputation_Poor  1.067336

# %% [markdown]
# Proceed to the next step if p-values and VIFs are within acceptable ranges.  If you observe high p-values or VIFs, create new cells to drop the features and retrain the model.

# %% [markdown]
# 7.2.5 Make predictions on training set <font color = "red">[2 Marks]</font>

# %%
# Predict the probabilities on the training set
y_train_pred_probs = result.predict(X_train_sm)

# %% [markdown]
# 7.2.6 Format the prediction output <font color="red">[1 Mark]</font>

# %%
# Reshape it into an array
y_train_pred_probs = y_train_pred_probs.values.reshape(-1)

# %% [markdown]
# 7.2.7 Create a DataFrame with the actual stayed flag and the predicted probabilities <font color="red">[1 Mark]</font>

# %%
# Create a new DataFrame containing the actual stayed flag and the probabilities predicted by the model
train_predictions = pd.DataFrame({
    "Actual": y_train_numeric,
    "Predicted_Prob": y_train_pred_probs
})

# %% [markdown]
# 7.2.8 Create a new column 'Predicted' with 1 if predicted probabilities are greater than 0.5 else 0 <font color = "red">[1 Mark]</font>

# %%
# Create a new column 'Predicted' with 1 if predicted probabilities are greater than 0.5 else 0
train_predictions["Predicted"] = train_predictions["Predicted_Prob"].apply(lambda x: 1 if x > 0.5 else 0)

# %% [markdown]
# **Evaluation of performance of Model**
#
# Evaluate the performance of the model based on the predictions made on the training set.

# %% [markdown]
# 7.2.9 Check the accuracy of the model based on the predictions made on the training set <font color = "red">[1 Mark]</font>

# %%
# Import metrics from sklearn for evaluation
from sklearn import metrics

# Check the overall accuracy
accuracy = metrics.accuracy_score(train_predictions["Actual"], train_predictions["Predicted"])
print("Training Accuracy:", accuracy)
# Out:
# Training Accuracy: 0.7391594531186797

# %% [markdown]
# 7.2.10 Create a confusion matrix based on the predictions made on the training set <font color="red">[1 mark]</font>

# %%
# Create confusion matrix
conf_matrix = metrics.confusion_matrix(train_predictions["Actual"], train_predictions["Predicted"])
print("Confusion Matrix:\n", conf_matrix)
# Out:
# Confusion Matrix:
#  [[17082  6577]
#  [ 6320 19465]]

# %% [markdown]
# 7.2.11 Create variables for true positive, true negative, false positive and false negative <font color="red">[1 Mark]</font>

# %%
# Create variables for true positive, true negative, false positive and false negative
tn, fp, fn, tp = conf_matrix.ravel()

# %% [markdown]
# 7.2.12 Calculate sensitivity and specificity of model  <font color="red">[2 Marks]</font>

# %%
# Calculate sensitivity
sensitivity = tp / (tp + fn)
print("Sensitivity:", sensitivity)
# Out:
# Sensitivity: 0.7548962575140585

# %%
# Calculate specificity
specificity = tn / (tn + fp)
print("Specificity:", specificity)
# Out:
# Specificity: 0.7220085379770912

# %% [markdown]
# 7.2.13 Calculate precision and recall of model <font color="red">[2 Marks]</font>

# %%
# Calculate precision
precision = tp / (tp + fp)
print("Precision:", precision)
# Out:
# Precision: 0.7474464326856616

# %%
# Calculate recall
recall = sensitivity  # Already calculated
print("Recall:", recall)
# Out:
# Recall: 0.7548962575140585

# %% [markdown]
# ### **7.3 Find the optimal cutoff** <font color = red>[15 marks]</font>
#
# Find the optimal cutoff to improve model performance. While a default threshold of 0.5 was used for initial evaluation, optimising this threshold can enhance the model's performance.
#
# First, plot the ROC curve and check AUC.

# %% [markdown]
# 7.3.1 Plot ROC curve <font color="red">[3 Marks]</font>

# %%
# Define ROC function
def plot_roc_curve(actuals, predicted_probs):
    from sklearn.metrics import roc_curve, roc_auc_score
    """
    Plots the ROC curve and prints the AUC score.

    Parameters:
    - actuals: array-like, true binary labels
    - predicted_probs: array-like, predicted probabilities from the model
    """
    fpr, tpr, thresholds = roc_curve(actuals, predicted_probs)
    auc_score = roc_auc_score(actuals, predicted_probs)

    plt.figure(figsize=(8, 6))
    plt.plot(fpr, tpr, label=f'AUC = {auc_score:.2f}')
    plt.plot([0, 1], [0, 1], 'k--')  # Diagonal line
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Curve')
    plt.legend(loc="lower right")
    plt.grid(True)
    plt.show()

    print(f"AUC Score: {auc_score:.4f}")

# %%
# Call the ROC function
plot_roc_curve(train_predictions["Actual"], train_predictions["Predicted_Prob"])
# Out:
# AUC Score: 0.8261

# %% [markdown]
# **Sensitivity and Specificity tradeoff**
#
# Check sensitivity and specificity tradeoff to find the optimal cutoff point.

# %% [markdown]
# 7.3.2 Predict on training set at various probability cutoffs <font color="red">[1 Mark]</font>

# %%
# Predict on training data by creating columns with different probability cutoffs to explore the impact of cutoff on model performance
# Define cutoff values from 0.01 to 0.99
cutoffs = np.arange(0.01, 1.0, 0.01)

# Initialize lists to store metrics
accuracy_scores = []
sensitivity_scores = []
specificity_scores = []

# Actual values
actual = train_predictions["Actual"]

# Loop through cutoff values
for cutoff in cutoffs:
    # Generate predicted class based on current cutoff
    predicted = train_predictions["Predicted_Prob"].apply(lambda x: 1 if x > cutoff else 0)

    # Confusion matrix
    tn, fp, fn, tp = metrics.confusion_matrix(actual, predicted).ravel()

    # Calculate metrics
    accuracy = (tp + tn) / (tp + tn + fp + fn)
    sensitivity = tp / (tp + fn)
    specificity = tn / (tn + fp)

    # Store values
    accuracy_scores.append(accuracy)
    sensitivity_scores.append(sensitivity)
    specificity_scores.append(specificity)

# %% [markdown]
# 7.3.3 Plot for accuracy, sensitivity, specificity at different probability cutoffs <font color="red">[2 Marks]</font>

# %%
# Create a DataFrame to see the values of accuracy, sensitivity, and specificity at different values of probability cutoffs
cutoff_metrics_df = pd.DataFrame({
    'Cutoff': cutoffs,
    'Accuracy': accuracy_scores,
    'Sensitivity': sensitivity_scores,
    'Specificity': specificity_scores
})

# Display the top of the DataFrame
print(cutoff_metrics_df.head())
# Out:
#    Cutoff  Accuracy  Sensitivity  Specificity
# 0    0.01  0.521519     1.000000     0.000042
# 1    0.02  0.523380     0.999961     0.003973
# 2    0.03  0.528295     0.999884     0.014329
# 3    0.04  0.535859     0.999690     0.030348
# 4    0.05  0.544920     0.999496     0.049495

# %%
# Plot accuracy, sensitivity, and specificity at different values of probability cutoffs
plt.figure(figsize=(10, 6))

# Plot all three metrics against the cutoff
plt.plot(cutoff_metrics_df['Cutoff'], cutoff_metrics_df['Accuracy'], label='Accuracy', color='blue')
plt.plot(cutoff_metrics_df['Cutoff'], cutoff_metrics_df['Sensitivity'], label='Sensitivity', color='green')
plt.plot(cutoff_metrics_df['Cutoff'], cutoff_metrics_df['Specificity'], label='Specificity', color='red')

# Labeling
plt.xlabel('Probability Cutoff')
plt.ylabel('Score')
plt.title('Accuracy, Sensitivity, Specificity vs Cutoff')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# 7.3.4 Create a column for final prediction based on the optimal cutoff <font color="red">[2 Marks]</font>

# %%
# Create a column for final prediction based on the optimal cutoff
# Find the cutoff where the difference between sensitivity and specificity is minimum
cutoff_metrics_df['Diff'] = abs(cutoff_metrics_df['Sensitivity'] - cutoff_metrics_df['Specificity'])
optimal_cutoff = cutoff_metrics_df.loc[cutoff_metrics_df['Diff'].idxmin(), 'Cutoff']

print(f"Optimal Cutoff (Sensitivity ≈ Specificity): {optimal_cutoff:.2f}")
# Out:
# Optimal Cutoff (Sensitivity ≈ Specificity): 0.52

# %% [markdown]
# 7.3.5 Calculate model's accuracy <font color="red">[1Mark]</font>

# %%
# Calculate the accuracy
from sklearn.metrics import accuracy_score
#  Create final prediction column based on this optimal cutoff
train_predictions["Final_Predicted"] = train_predictions["Predicted_Prob"].apply(
    lambda x: 1 if x > optimal_cutoff else 0
)
final_accuracy = accuracy_score(train_predictions["Actual"], train_predictions["Final_Predicted"])
print(f"Model Accuracy at Optimal Cutoff ({optimal_cutoff:.2f}): {final_accuracy:.4f}")
# Out:
# Model Accuracy at Optimal Cutoff (0.52): 0.7387

# %% [markdown]
# 7.3.6 Create confusion matrix <font color="red">[1Mark]</font>

# %%
# Create the confusion matrix once again
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(train_predictions["Actual"], train_predictions["Final_Predicted"])

print("Confusion Matrix:")
print(cm)
# Out:
# Confusion Matrix:
# [[17513  6146]
#  [ 6775 19010]]

# %% [markdown]
# 7.3.7 Create variables for true positive, true negative, false positive and false negative <font color="red">[1Mark]</font>

# %%
# Create variables for true positive, true negative, false positive and false negative
tn, fp, fn, tp = cm.ravel()

# Now you have variables for each category:
print(f"True Positive (TP): {tp}")
print(f"True Negative (TN): {tn}")
print(f"False Positive (FP): {fp}")
print(f"False Negative (FN): {fn}")
# Out:
# True Positive (TP): 19010
# True Negative (TN): 17513
# False Positive (FP): 6146
# False Negative (FN): 6775

# %% [markdown]
# 7.3.8 Calculate sensitivity and specificity of the model <font color="red">[1Mark]</font>

# %%
# Calculate Sensitivity
sensitivity = tp / (tp + fn)
print(f"Sensitivity: {sensitivity:.4f}")
# Out:
# Sensitivity: 0.7373

# %%
# Calculate Specificity
specificity = tn / (tn + fp)
print(f"Specificity: {specificity:.4f}")
# Out:
# Specificity: 0.7402

# %% [markdown]
# 7.3.9 Calculate precision and recall of the model <font color="red">[1Mark]</font>

# %%
# Calculate Precision
precision = tp / (tp + fp)
print(f"Precision: {precision:.4f}")
# Out:
# Precision: 0.7557

# %%
# Calculate Recall
recall = tp / (tp + fn)
print(f"Recall: {recall:.4f}")
# Out:
# Recall: 0.7373

# %% [markdown]
# **Precision and Recall tradeoff**
#
# Check optimal cutoff value by plotting precision-recall curve, and adjust the cutoff based on the precision and recall tradeoff if required.

# %%
# Import precision-recall curve function
from sklearn.metrics import precision_recall_curve

# %%
# Check actual and predicted values from initial model
y_true = train_predictions["Actual"]

# Predicted probabilities
y_scores = train_predictions["Predicted_Prob"]

# Get precision, recall, thresholds
precision_vals, recall_vals, pr_thresholds = precision_recall_curve(y_true, y_scores)

# %% [markdown]
# 7.3.10 Plot precision-recall curve <font color="red">[2 Marks]</font>

# %%
# Plot precision-recall curve
plt.figure(figsize=(8,6))
plt.plot(recall_vals, precision_vals, color='b', label='Precision-Recall curve')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## **8. Prediction and Model Evaluation** <font color = red>[30 marks]</font>
#
# Use the model from the previous step to make predictions on the validation set with the optimal cutoff. Then evaluate the model's performance using metrics such as accuracy, sensitivity, specificity, precision, and recall.

# %% [markdown]
# ### **8.1 Make predictions over validation set** <font color = red>[15 marks]</font>

# %% [markdown]
# 8.1.1 Select relevant features for validation set <font color="red">[2 Marks]</font>

# %%
# Select the relevant features for validation set
# One-hot encode validation dataset
X_val_encoded = pd.get_dummies(X_val, drop_first=True)

# Align validation dataset with training dummy columns
X_val_encoded = X_val_encoded.reindex(columns=dummies.columns, fill_value=0)

# Use the RFE-selected columns stored in 'col'
X_val_selected = X_val_encoded[col]

# %% [markdown]
# 8.1.2 Add constant to X_validation <font color="red">[2 Marks]</font>

# %%
# Add constant to X_validation
import statsmodels.api as sm

# Add constant to the validation feature set
X_val_selected_const = sm.add_constant(X_val_selected, has_constant='add')
X_val_selected_const.head()
# Out:
#        const  Gender_Male  Work-Life Balance_Fair  Work-Life Balance_Poor  \
# 23813    1.0         True                   False                   False
# 14537    1.0         True                    True                   False
# 45192    1.0         True                   False                    True
# 13765    1.0        False                   False                    True
# 3411     1.0         True                   False                   False
#
#        Job Satisfaction_Low  Job Satisfaction_Very High  \
# 23813                 False                        True
# 14537                 False                       False
# 45192                 False                       False
# 13765                  True                       False
# 3411                  False                       False
#
#        Performance Rating_Below Average  Performance Rating_Low  Overtime_Yes  \
# 23813                             False                   False         False
# ...

# %% [markdown]
# 8.1.3 Make predictions over validation set <font color="red">[3 Marks]</font>

# %%
# Make predictions on the validation set and store it in the variable 'y_validation_pred'
# Align validation columns with training model
X_val_selected_const = X_val_selected_const[X_train_sm.columns]

# Convert boolean columns to integers (True/False → 1/0)
X_val_selected_const = X_val_selected_const.astype(int)

# Now make predictions
y_validation_pred = result.predict(X_val_selected_const)

# View results
print(y_validation_pred.head())

y_validation_pred = result.predict(X_val_selected_const)

# 4. View predictions
print(y_validation_pred.head())
# Out:
# 23813    0.946923
# 14537    0.266727
# 45192    0.396343
# 13765    0.083073
# 3411     0.940507
# dtype: float64
# 23813    0.946923
# 14537    0.266727
# 45192    0.396343
# 13765    0.083073
# 3411     0.940507
# dtype: float64

# %% [markdown]
# 8.1.4 Create DataFrame with actual values and predicted values for validation set <font color="red">[5 Marks]</font>

# %%
# Ensure y_validation is defined (you can skip this if already assigned)
y_validation = y_val  # Assuming y_val was created during train-test split

# 1. Convert predicted probabilities to a DataFrame
predicted_probability = pd.DataFrame(y_validation_pred, columns=['predicted_probability'])

# 2. Convert actual validation labels to a DataFrame
actual = pd.DataFrame(y_validation.values, columns=['actual'])

# 3. Reset index for both DataFrames
predicted_probability.reset_index(drop=True, inplace=True)
actual.reset_index(drop=True, inplace=True)

# 4. Combine side by side
validation_results = pd.concat([actual, predicted_probability], axis=1)

# 5. View the combined DataFrame
print(validation_results.head(20))
# Out:
#     actual  predicted_probability
# 0   Stayed               0.946923
# 1     Left               0.266727
# 2     Left               0.396343
# 3     Left               0.083073
# 4   Stayed               0.940507
# 5     Left               0.433286
# 6   Stayed               0.578743
# 7   Stayed               0.905997
# 8     Left               0.366248
# 9     Left               0.092796
# 10  Stayed               0.949707
# 11  Stayed               0.864575
# 12  Stayed               0.898397
# 13  Stayed               0.567756
# 14  Stayed               0.774893
# 15    Left               0.513544
# 16  Stayed               0.271087
# 17  Stayed               0.386852
# 18  Stayed               0.564659
# 19    Left               0.175804

# %% [markdown]
# 8.1.5 Predict final prediction based on the cutoff value <font color="red">[3 Marks]</font>

# %%
# Make predictions on the validation set using the optimal cutoff and store it in a column 'final_prediction'

# Make predictions using the cutoff and add to the DataFrame
validation_results['final_prediction'] = (validation_results['predicted_probability'] >= optimal_cutoff).astype(int)

# Check the updated DataFrame
print(validation_results.head(20))
# Check the DataFrame
# Out:
#     actual  predicted_probability  final_prediction
# 0   Stayed               0.946923                 1
# 1     Left               0.266727                 0
# 2     Left               0.396343                 0
# 3     Left               0.083073                 0
# 4   Stayed               0.940507                 1
# 5     Left               0.433286                 0
# 6   Stayed               0.578743                 1
# 7   Stayed               0.905997                 1
# 8     Left               0.366248                 0
# 9     Left               0.092796                 0
# 10  Stayed               0.949707                 1
# 11  Stayed               0.864575                 1
# 12  Stayed               0.898397                 1
# 13  Stayed               0.567756                 1
# 14  Stayed               0.774893                 1
# 15    Left               0.513544                 1
# 16  Stayed               0.271087                 0
# ...

# %% [markdown]
# ### **8.2 Calculate accuracy of the model** <font color = red>[2 marks]</font>

# %%
# Map string labels to integers
label_mapping = {'Stayed': 1, 'Left': 0}
validation_results['actual_mapped'] = validation_results['actual'].map(label_mapping)

# Now calculate accuracy
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(validation_results['actual_mapped'], validation_results['final_prediction'])
print(f"Overall Accuracy: {accuracy:.4f}")
# Out:
# Overall Accuracy: 0.7364

# %% [markdown]
# ### **8.3 Create confusion matrix and create variables for true positive, true negative, false positive and false negative** <font color = red>[5 marks]</font>

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Confusion matrix
cm = confusion_matrix(validation_results['actual_mapped'], validation_results['final_prediction'])

# Plot it
plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Predicted Stayed', 'Predicted Left'],
            yticklabels=['Actual Stayed', 'Actual Left'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.tight_layout()
plt.show()

# %%
# Create variables for true positive, true negative, false positive and false negative

# %% [markdown]
# ### **8.4 Calculate sensitivity and specificity** <font color = red>[4 marks]</font>

# %%
# Calculate sensitivity
from sklearn.metrics import recall_score

# Calculate sensitivity / recall for the "Left" class (encoded as 1)
sensitivity = recall_score(validation_results['actual_mapped'], validation_results['final_prediction'])

print(f"Sensitivity (Recall for class 'Stayed'): {sensitivity:.4f}")
# Out:
# Sensitivity (Recall for class 'Stayed'): 0.7479

# %%
# Calculate specificity
from sklearn.metrics import confusion_matrix

# Get confusion matrix
cm = confusion_matrix(validation_results['actual_mapped'], validation_results['final_prediction'])

# Extract TN, FP, FN, TP
tn, fp, fn, tp = cm.ravel()

# Calculate specificity
specificity = tn / (tn + fp)

print(f"Specificity (True Negative Rate for 'Stayed'): {specificity:.4f}")
# Out:
# Specificity (True Negative Rate for 'Stayed'): 0.7240

# %% [markdown]
# ### **8.5 Calculate precision and recall** <font color = red>[4 marks]</font>

# %%
# Calculate precision
from sklearn.metrics import precision_score
precision = precision_score(validation_results['actual_mapped'], validation_results['final_prediction'])

print(f"Precision (for class 'Stayed 1'): {precision:.4f}")
# Out:
# Precision (for class 'Stayed 1'): 0.7461

# %%
# Calculate recall
from sklearn.metrics import recall_score

# Calculate recall for class 'Stayed' (1)
recall = recall_score(validation_results['actual_mapped'], validation_results['final_prediction'])

print(f"Recall (Sensitivity for class 'Left'): {recall:.4f}")
# Out:
# Recall (Sensitivity for class 'Left'): 0.7479

# %% [markdown]
# ## Conclusion
